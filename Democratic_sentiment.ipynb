# %% [markdown]
# # 2020 Democratic Primary Elections

# %%
# %run stream_functions.py

# %%
sns.set()
# %matplotlib inline

# %% [markdown]
# <img src="2020graphic.png" width=1000 height=600 align="center">

# %%
Sentiment()
